# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Creating Dataframes

# %%
# Create series from dictionary
pd.Series({'a': 1, 'b': 3, 'c': 7, 'd': 9}, name='number')
# Out:
# a    1
# b    3
# c    7
# d    9
# Name: number, dtype: int64

# %%
# Create dataframe from dictionary of dictionaries
# Each subdictionary is a column
pd.DataFrame({'number':{'a': 1, 'b': 3, 'c': 7, 'd': 9},
              'double':{'a': 2, 'b': 6, 'c': 14,'d': 18},
              'square':{'a': 1, 'b': 9, 'c': 49,'d': 81}})
# Out:
#    number  double  square
# a       1       2       1
# b       3       6       9
# c       7      14      49
# d       9      18      81

# %%
df = pd.read_csv('titanic.csv') # Loads dataframe from a csv file
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
# More options at https://pandas.pydata.org/docs/reference/io.html

# %% [markdown]
# # Selecting Data

# %%
df['survived'] # Returns column titled 'survived'
# We can usually use dot notation as well (e.g. df.survived)
# This doesn't work when the column name is a Python keyword or
# method name (e.g. df.class throws an error)
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %%
df[1:3] # Returns row 1, refers to index value
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
df[df.survived==1] # Returns rows where survived==1
# df[df.who.isin(['woman','child'])] # Returns rows where who is in [woman, child]
# df[df.embark_town.notnull()] # Returns rows where embark_town is not null
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 8    woman       False  NaN  Southampton   yes  False
# 9    child       False  NaN    Cherbourg   yes  False
# ..     ...         ...  ...          ...   ...    ...
# 875  child       False  NaN    Cherbourg   yes   True
# 879  woman       False    C    Cherbourg   yes  False
# 880  woman       False  NaN  Southampton   yes  False
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
#
# [342 rows x 15 columns]

# %%
df.iloc[0:2, 1:4] # Returns rows by index number (exclude end)
# df.iloc[[0,1],[1,2,3]] # Does the same thing
# Out:
#    pclass     sex   age
# 0       3    male  22.0
# 1       1  female  38.0

# %%
df.loc[0:1, 'pclass':'age'] # Gets rows by index value (include end)
# df.loc[[0,1],['pclass','sex','age']] # Does the same thing
# Out:
#    pclass     sex   age
# 0       3    male  22.0
# 1       1  female  38.0

# %% [markdown]
# # Data Exploration

# %%
df.head() # Returns first 5 rows
# df.head(n=10) # Returns first 10 rows
# df.tail(n=3) # Returns last 3 rows
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.shape # Returns number of rows and columns in dataframe
# Out:
# (891, 15)

# %%
df.info() # Prints index, datatype and memory information
# df.index.dtype # Returns datatype of index
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
df.describe() # Returns summary statistics for numerical columns
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.select_dtypes(include='number').corr() # Returns correlation between numerical and boolean columns
# Out:
#           survived    pclass       age     sibsp     parch      fare
# survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
df.columns # Returns dataframe columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.who.unique() # Returns set of unique values for column
# df.who.value_counts() # Returns unique values with counts
# Out:
# array(['man', 'woman', 'child'], dtype=object)

# %% [markdown]
# # Data Manipulation

# %%
df.dropna() # Drops and returns all rows that contain null values
# df.dropna(axis=1) # Drops and returns all columns that contain null values
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 3    woman       False    C  Southampton   yes  False
# 6      man        True    E  Southampton    no   True
# 10   child       False    G  Southampton   yes  False
# 11   woman       False    C  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 871  woman       False    D  Southampton   yes  False
# 872    man        True    B  Southampton    no   True
# 879  woman       False    C    Cherbourg   yes  False
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
#
# [182 rows x 15 columns]

# %%
df.fillna(0) # Replaces NaNs with x
# df.fillna(df.mean()) # Fills NaNs using column mean
# df.ffill() # Fills NaNs using previous row value
# df.bfill() # Fills NaNs using next row value
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   0.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True    0  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False    0  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True    0  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True    0  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False    0  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True    0   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df['class'].replace('Third','3rd') # Replaces matches with new string
# df.embark_town.str.match('Cher.*') # Returns regex matches of strings on column
# Out:
# 0         3rd
# 1       First
# 2         3rd
# 3       First
# 4         3rd
#         ...
# 886    Second
# 887     First
# 888       3rd
# 889     First
# 890       3rd
# Name: class, Length: 891, dtype: object

# %%
df.survived + df.pclass # Adds two columns
# Can use + - * / // % ** | & ~ > >= < <=
# Out:
# 0      3
# 1      2
# 2      4
# 3      2
# 4      3
#       ..
# 886    2
# 887    2
# 888    3
# 889    2
# 890    3
# Length: 891, dtype: int64

# %%
df.survived.astype(float) # Changes type of column
# df.survived.astype(str) # Changes type of column
# df.survived.astype(np.dtype('ufloat64')) # Changes type of column
# Out:
# 0      0.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      0.0
#       ...
# 886    0.0
# 887    1.0
# 888    0.0
# 889    1.0
# 890    0.0
# Name: survived, Length: 891, dtype: float64

# %%
df.sex.str.upper() # Applies string function to column
# More string functions at https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html
# Out:
# 0        MALE
# 1      FEMALE
# 2      FEMALE
# 3      FEMALE
# 4        MALE
#         ...
# 886      MALE
# 887    FEMALE
# 888    FEMALE
# 889      MALE
# 890      MALE
# Name: sex, Length: 891, dtype: object

# %%
df.apply(lambda x: x[0]) # Applies custom function to df columns (default axis is 'index')
# df.apply(lambda x: x['survived']+x['pclass'], axis='columns') # Applies custom function to df rows
# df.sex.map(lambda x: x[0]) # Applies custom function to series
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                   22.0
# sibsp                    1
# parch                    0
# fare                  7.25
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                False
# dtype: object

# %%
# df1.join(df2,on=col1,how='inner') # SQL-style joins the columns in df1 with the columns on df2
#                                   # where the rows for col1 have identical values.
#                                   # how can be one of 'left', 'right', 'outer', 'inner'
#                                   # TODO

# %%
# pd.concat([df1, df2],axis=1) # Adds the columns in df1 to the end of df2 (rows should be identical) #TODO

# %%
# df1.append(df2) # Adds the rows in df1 to the end of df2 (columns should be identical) #TODO
# pd.concat([df1,df2]) # Adds the rows in df1 to the end of df2 (columns should be identical)

# %%
# df.eval()  #TODO
# df.query() #TODO

# %%
#TODO Datetime https://strftime.org

# %%
df.sort_values(by='fare') # Sort dataframe by column
# df.sort_values(by=['fare', 'embark_town']) # Sort dataframe by multiple columns
# df.sort_index() # Sort dataframe by index value
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 271         1       3    male  25.0      0      0    0.0000        S   Third
# 597         0       3    male  49.0      0      0    0.0000        S   Third
# 302         0       3    male  19.0      0      0    0.0000        S   Third
# 633         0       1    male   NaN      0      0    0.0000        S   First
# 277         0       2    male   NaN      0      0    0.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 438         0       1    male  64.0      1      4  263.0000        S   First
# 341         1       1  female  24.0      3      2  263.0000        S   First
# 737         1       1    male  35.0      0      0  512.3292        C   First
# 258         1       1  female  35.0      0      0  512.3292        C   First
# 679         1       1    male  36.0      0      1  512.3292        C   First
#
#        who  adult_male deck  embark_town alive  alone
# 271    man        True  NaN  Southampton   yes   True
# 597    man        True  NaN  Southampton    no   True
# 302    man        True  NaN  Southampton    no   True
# 633    man        True  NaN  Southampton    no   True
# 277    man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 438    man        True    C  Southampton    no  False
# 341  woman       False    C  Southampton   yes  False
# 737    man        True    B    Cherbourg   yes   True
# 258  woman       False  NaN    Cherbourg   yes   True
# 679    man        True    B    Cherbourg   yes  False
#
# [891 rows x 15 columns]

# %% [markdown]
# # MultiIndex, Groupby, Pivot

# %%
df.set_index('survived') # Sets the index as survived
# Out:
#           pclass     sex   age  sibsp  parch     fare embarked   class    who  \
# survived
# 0              3    male  22.0      1      0   7.2500        S   Third    man
# 1              1  female  38.0      1      0  71.2833        C   First  woman
# 1              3  female  26.0      0      0   7.9250        S   Third  woman
# 1              1  female  35.0      1      0  53.1000        S   First  woman
# 0              3    male  35.0      0      0   8.0500        S   Third    man
# ...          ...     ...   ...    ...    ...      ...      ...     ...    ...
# 0              2    male  27.0      0      0  13.0000        S  Second    man
# 1              1  female  19.0      0      0  30.0000        S   First  woman
# 0              3  female   NaN      1      2  23.4500        S   Third  woman
# 1              1    male  26.0      0      0  30.0000        C   First    man
# 0              3    male  32.0      0      0   7.7500        Q   Third    man
#
#           adult_male deck  embark_town alive  alone
# survived
# 0               True  NaN  Southampton    no  False
# 1              False    C    Cherbourg   yes  False
# 1              False  NaN  Southampton   yes   True
# 1              False    C  Southampton   yes  False
# 0               True  NaN  Southampton    no   True
# ...              ...  ...          ...   ...    ...
# 0               True  NaN  Southampton    no   True
# 1              False    B  Southampton   yes   True
# 0              False  NaN  Southampton    no  False
# 1               True    C    Cherbourg   yes   True
# 0               True  NaN   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
df.set_index(['survived','pclass']) # Sets Multindex as [survived, pclass]
# Out:
#                     sex   age  sibsp  parch     fare embarked   class    who  \
# survived pclass
# 0        3         male  22.0      1      0   7.2500        S   Third    man
# 1        1       female  38.0      1      0  71.2833        C   First  woman
#          3       female  26.0      0      0   7.9250        S   Third  woman
#          1       female  35.0      1      0  53.1000        S   First  woman
# 0        3         male  35.0      0      0   8.0500        S   Third    man
# ...                 ...   ...    ...    ...      ...      ...     ...    ...
#          2         male  27.0      0      0  13.0000        S  Second    man
# 1        1       female  19.0      0      0  30.0000        S   First  woman
# 0        3       female   NaN      1      2  23.4500        S   Third  woman
# 1        1         male  26.0      0      0  30.0000        C   First    man
# 0        3         male  32.0      0      0   7.7500        Q   Third    man
#
#                  adult_male deck  embark_town alive  alone
# survived pclass
# 0        3             True  NaN  Southampton    no  False
# 1        1            False    C    Cherbourg   yes  False
#          3            False  NaN  Southampton   yes   True
#          1            False    C  Southampton   yes  False
# 0        3             True  NaN  Southampton    no   True
# ...                     ...  ...          ...   ...    ...
#          2             True  NaN  Southampton    no   True
# 1        1            False    B  Southampton   yes   True
# 0        3            False  NaN  Southampton    no  False
# 1        1             True    C    Cherbourg   yes   True
# 0        3             True  NaN   Queenstown    no   True
#
# [891 rows x 13 columns]

# %%
df.reset_index() # Adds numeric index to df
# Out:
#      index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0        0         0       3    male  22.0      1      0   7.2500        S
# 1        1         1       1  female  38.0      1      0  71.2833        C
# 2        2         1       3  female  26.0      0      0   7.9250        S
# 3        3         1       1  female  35.0      1      0  53.1000        S
# 4        4         0       3    male  35.0      0      0   8.0500        S
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 886    886         0       2    male  27.0      0      0  13.0000        S
# 887    887         1       1  female  19.0      0      0  30.0000        S
# 888    888         0       3  female   NaN      1      2  23.4500        S
# 889    889         1       1    male  26.0      0      0  30.0000        C
# 890    890         0       3    male  32.0      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# 0     Third    man        True  NaN  Southampton    no  False
# 1     First  woman       False    C    Cherbourg   yes  False
# 2     Third  woman       False  NaN  Southampton   yes   True
# 3     First  woman       False    C  Southampton   yes  False
# 4     Third    man        True  NaN  Southampton    no   True
# ..      ...    ...         ...  ...          ...   ...    ...
# 886  Second    man        True  NaN  Southampton    no   True
# 887   First  woman       False    B  Southampton   yes   True
# 888   Third  woman       False  NaN  Southampton    no  False
# 889   First    man        True    C    Cherbourg   yes   True
# 890   Third    man        True  NaN   Queenstown    no   True
#
# [891 rows x 16 columns]

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df.groupby('class')

# %%
df.select_dtypes(include=np.number).columns
# Out:
# Index(['survived', 'pclass', 'age', 'sibsp', 'parch', 'fare'], dtype='object')

# %%
numeric_cols = df.select_dtypes(include=np.number).columns
df.groupby('class')[numeric_cols].mean() # Gets mean of numeric columns based on class
# .size(), .describe(), .first(), etc
# Out:
#         survived  pclass        age     sibsp     parch       fare
# class
# First   0.629630     1.0  38.233441  0.416667  0.356481  84.154687
# Second  0.472826     2.0  29.877630  0.402174  0.380435  20.662183
# Third   0.242363     3.0  25.140620  0.615071  0.393075  13.675550

# %%
df.groupby('class')[numeric_cols].agg(['mean', 'std']) # Aggregates multiple functions at once
# Out:
#         survived           pclass             age                sibsp  \
#             mean       std   mean  std       mean        std      mean
# class
# First   0.629630  0.484026    1.0  0.0  38.233441  14.802856  0.416667
# Second  0.472826  0.500623    2.0  0.0  29.877630  14.001077  0.402174
# Third   0.242363  0.428949    3.0  0.0  25.140620  12.495398  0.615071
#
#                      parch                 fare
#              std      mean       std       mean        std
# class
# First   0.611898  0.356481  0.693997  84.154687  78.380373
# Second  0.601633  0.380435  0.690963  20.662183  13.417399
# Third   1.374883  0.393075  0.888861  13.675550  11.778142

# %%
df.groupby('class').age.agg(lambda x: (x>30).sum()) # Aggregate class groups using custom function, how many people older than 30
# Out:
# class
# First     125
# Second     77
# Third     103
# Name: age, dtype: int64

# %%
# More info and methods at https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html
# Also look at https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html

# %%
df.pivot_table('survived', index='class', columns='sex') # Gets mean of survived based on class and sex
# Out:
# sex       female      male
# class
# First   0.968085  0.368852
# Second  0.921053  0.157407
# Third   0.500000  0.135447

# %%
# More info and methods at https://jakevdp.github.io/PythonDataScienceHandbook/03.09-pivot-tables.html

# %%
df_pivot = df.pivot_table('survived', index=['class','embark_town'], columns=['sex','who'])
# df_pivot = df.pivot_table('survived', index=['class','embark_town'], columns=['sex','who'], aggfunc='sum')
df_pivot
# Out:
# sex                   female            male
# who                    child     woman child       man
# class  embark_town
# First  Cherbourg         NaN  0.976744   NaN  0.404762
#        Queenstown        NaN  1.000000   NaN  0.000000
#        Southampton  0.666667  0.977778  1.00  0.328947
# Second Cherbourg    1.000000  1.000000  1.00  0.111111
#        Queenstown        NaN  1.000000   NaN  0.000000
#        Southampton  1.000000  0.898305  1.00  0.078652
# Third  Cherbourg    0.818182  0.500000  0.50  0.205128
#        Queenstown   1.000000  0.718750  0.00  0.085714
#        Southampton  0.333333  0.385714  0.35  0.110204

# %%
df_pivot.stack() # Turns a column label into a row label
# Out:
# sex                         female      male
# class  embark_town who
# First  Cherbourg   man         NaN  0.404762
#                    woman  0.976744       NaN
#        Queenstown  man         NaN  0.000000
#                    woman  1.000000       NaN
#        Southampton child  0.666667  1.000000
#                    man         NaN  0.328947
#                    woman  0.977778       NaN
# Second Cherbourg   child  1.000000  1.000000
#                    man         NaN  0.111111
#                    woman  1.000000       NaN
#        Queenstown  man         NaN  0.000000
#                    woman  1.000000       NaN
#        Southampton child  1.000000  1.000000
#                    man         NaN  0.078652
#                    woman  0.898305       NaN
# Third  Cherbourg   child  0.818182  0.500000
#                    man         NaN  0.205128
#                    woman  0.500000       NaN
#        Queenstown  child  1.000000  0.000000
#                    man         NaN  0.085714
#                    woman  0.718750       NaN
#        Southampton child  0.333333  0.350000
#                    man         NaN  0.110204
#                    woman  0.385714       NaN

# %%
df_pivot.unstack() # Turns a row label into a column label
# Out:
# sex            female                                                          \
# who             child                            woman
# embark_town Cherbourg Queenstown Southampton Cherbourg Queenstown Southampton
# class
# First             NaN        NaN    0.666667  0.976744    1.00000    0.977778
# Second       1.000000        NaN    1.000000  1.000000    1.00000    0.898305
# Third        0.818182        1.0    0.333333  0.500000    0.71875    0.385714
#
# sex              male
# who             child                              man
# embark_town Cherbourg Queenstown Southampton Cherbourg Queenstown Southampton
# class
# First             NaN        NaN        1.00  0.404762   0.000000    0.328947
# Second            1.0        NaN        1.00  0.111111   0.000000    0.078652
# Third             0.5        0.0        0.35  0.205128   0.085714    0.110204
